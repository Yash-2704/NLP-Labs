# %% [markdown]
# # Experiment-1.1: Read the employee dataset and display the average salary of each department using a bar chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/yash/Downloads/NLP Labs/Lab 1/employee_information_100.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employee_ID       100 non-null    str
#  1   Name              100 non-null    str
#  2   Department        100 non-null    str
#  3   Age               100 non-null    int64
#  4   Gender            100 non-null    str
#  5   Salary            100 non-null    int64
#  6   Experience_Years  100 non-null    int64
# dtypes: int64(3), str(4)
# memory usage: 5.6 KB

# %%
dept_wise_avg_salary=df.groupby('Department')['Salary'].mean().sort_values(ascending=False)

# %%
dept_wise_avg_salary.plot(kind='bar', color='gold', edgecolor='black', figsize=(10, 6))
plt.title('Average Salary by Department')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.show()

# %%
df.head()
# Out:
#   Employee_ID    Name  Department  Age  Gender  Salary  Experience_Years
# 0        E001  Diana1          HR   39    Male   58000                 8
# 1        E002  Diana2  Operations   56    Male  105000                27
# 2        E003    Bob3          HR   27    Male   59000                32
# 3        E004   Neha4          HR   57    Male  113000                34
# 4        E005  Nisha5          IT   50  Female   30000                10

# %% [markdown]
# # Experiment 1.2: Display the number of employees working in each department.

# %%
count=df['Department'].value_counts()

# %%
count.plot(kind='bar', color='lightblue', edgecolor='black', figsize=(10, 6))
plt.title('Number of Employees by Department')
plt.xlabel('Department')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# # Experiment 1.3:Display the percentage of male and female employees using a pie chart

# %%
gender = df.groupby('Gender')["Gender"].count()

# %%
gender
# Out:
# Gender
# Female    36
# Male      64
# Name: Gender, dtype: int64

# %%
gender.plot(kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'], startangle=90, figsize=(8, 8))
# Out:
# <Axes: >

# %% [markdown]
# # Experiment 1.4: Draw a histogram showing salary distribution.

# %%
df["Salary"].plot(kind='hist', bins=10, color='lightgreen', edgecolor='black', figsize=(10, 6))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Experiment 1.5: Draw a scatter plot showing the relationship between experience and salary.

# %%
plt.scatter(df['Salary'], df['Experience_Years'],color='purple', alpha=0.5)
plt.title('Salary vs Experience Years')
# Out:
# Text(0.5, 1.0, 'Salary vs Experience Years')

# %% [markdown]
# # Experiment 1.6: Display the top 10 employees with the highest salary.

# %%
df["Salary"].sort_values(ascending=False).head(10).plot(kind='bar', color='orange', edgecolor='black', figsize=(10, 6))
# Out:
# <Axes: >

# %% [markdown]
# # Experiment 1.7: Find the highest salary in every department.

# %%
highest_salary_in_every_department=df.groupby("Department")["Salary"].max()

# %%
highest_salary_in_every_department.plot(kind='bar', color='lightblue', edgecolor='black', figsize=(10, 6))
plt.title('Highest Salary in Every Department')
plt.xlabel('Department')
plt.ylabel('Highest Salary')
plt.show()

# %% [markdown]
# # Experiment 1.8: Display employees whose salary is greater than the overall average salary.

# %%
meane=df["Salary"].mean()

# %%
df[df["Salary"] > meane].head()
# Out:
#   Employee_ID      Name  Department  Age  Gender  Salary  Experience_Years
# 1        E002    Diana2  Operations   56    Male  105000                27
# 3        E004     Neha4          HR   57    Male  113000                34
# 7        E008     Neha8     Finance   24  Female   98000                 7
# 8        E009    Mohan9          HR   57  Female  110000                23
# 9        E010  Vikram10          IT   26    Male  114000                14

# %% [markdown]
# # Experiment 1.9: Calculate the average years of experience in each department.

# %%
df.groupby("Department")["Experience_Years"].mean()
# Out:
# Department
# Finance       11.166667
# HR            19.809524
# IT            18.388889
# Marketing     21.900000
# Operations    16.875000
# Sales         23.846154
# Name: Experience_Years, dtype: float64

# %% [markdown]
# # Experiment 1.10: Display the distribution of employee ages using a histogram.

# %%
ages=df["Age"]

# %%
ages.plot(kind='hist', bins=10, color='lightyellow', edgecolor='black', figsize=(10, 6))
# Out:
# <Axes: ylabel='Frequency'>
